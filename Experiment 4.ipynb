# %% [markdown]
# # STOCK PREDICTION

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading The Dataset

# %%
df = pd.read_csv('NVIDIA.csv')
df.head()
# Out:
#         Date    Open    High     Low   Close     Volume
# 0  9/30/2024  118.31  121.50  118.15  121.44  227053703
# 1  9/27/2024  123.97  124.03  119.26  121.40  271009219
# 2  9/26/2024  126.80  127.67  121.80  124.04  302582906
# 3  9/25/2024  122.02  124.94  121.61  123.51  284692906
# 4  9/24/2024  116.52  121.80  115.38  120.87  354966781

# %% [markdown]
# ## Data Preprocessing

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df.sort_index(inplace=True)
df.head()
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2024-09-03  116.01  116.21  107.29  108.00  474972000
# 2024-09-04  105.41  113.27  104.12  106.21  372470312
# 2024-09-05  104.99  109.65  104.76  107.21  306850688
# 2024-09-06  108.04  108.15  100.95  102.83  413638125
# 2024-09-09  104.88  106.55  103.69  106.47  273912000

# %% [markdown]
# ## Dividing Data Into Target Variable & Independent Variable

# %%
input
# Out:
# array([[1.16010000e+02, 1.16210000e+02, 1.07290000e+02, 4.74972000e+08],
#        [1.05410000e+02, 1.13270000e+02, 1.04120000e+02, 3.72470312e+08],
#        [1.04990000e+02, 1.09650000e+02, 1.04760000e+02, 3.06850688e+08],
#        [1.08040000e+02, 1.08150000e+02, 1.00950000e+02, 4.13638125e+08],
#        [1.04880000e+02, 1.06550000e+02, 1.03690000e+02, 2.73912000e+08],
#        [1.07810000e+02, 1.09400000e+02, 1.04950000e+02, 2.68283688e+08],
#        [1.09390000e+02, 1.17190000e+02, 1.07420000e+02, 4.41422406e+08],
#        [1.16840000e+02, 1.20790000e+02, 1.15380000e+02, 3.67100500e+08],
#        [1.19080000e+02, 1.19960000e+02, 1.17600000e+02, 2.38358297e+08],
#        [1.16790000e+02, 1.18180000e+02, 1.14360000e+02, 2.48772297e+08],
#        [1.18170000e+02, 1.18800000e+02, 1.14830000e+02, 2.31925906e+08],
#        [1.15890000e+02, 1.17700000e+02, 1.13220000e+02, 3.10318906e+08],
#        [1.17350000e+02, 1.19660000e+02, 1.17250000e+02, 2.93506406e+08],
# ...

# %%
target
# Out:
# array([108.  , 106.21, 107.21, 102.83, 106.47, 108.1 , 116.91, 119.14,
#        119.1 , 116.78, 115.59, 113.37, 117.87, 116.  , 116.26, 120.87,
#        123.51, 124.04, 121.4 , 121.44])

# %% [markdown]
# ## Training The Model

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(input, target, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Making Prediction

# %%
y_pred = model.predict(x_test)
y_pred
model.predict([[116.79,118.18,114.36,248772297]])
# Out:
# array([116.31580298])

# %% [markdown]
# ## Measuring Metrics

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.7443173119133235

# %% [markdown]
# ## Plotting Graph

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
plt.scatter(y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
pred_y_df = pd.DataFrame({'Actual Value':y_test, 'Predicted Value':y_pred, 'Difference':y_test - y_pred})
pred_y_df[0:20]
# Out:
#    Actual Value  Predicted Value  Difference
# 0        121.40       120.256571    1.143429
# 1        106.21       113.254262   -7.044262
# 2        121.44       121.356013    0.083987
# 3        119.10       118.257122    0.842878
# 4        115.59       116.480546   -0.890546
# 5        124.04       123.589760    0.450240
